# %%
# %load_ext autoreload
# %autoreload 2
import PIL
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import planner

# %%
img = PIL.Image.open("../data/32_b.png")
plt.imshow(img)

# %%
# An mxn array where element value of 1 is filled space, and element value of 0 is empty space
imgarr = np.asarray(img).astype(float) / 255.0
np.shape(imgarr)
# Out:
# (1608, 2167)

# %%
start = np.array([600, 750])
end = np.array([1000, 2000])

# Create an instance of the PathPlanner class:
test_planner = planner.PathPlanner(imgarr)

# Plan a path. Don't know why this prints so many things.
start, path = test_planner.a_star(start, end)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a1a975638da8> in <module>
#       6
#       7 # Plan a path. Don't know why this prints so many things.
# ----> 8 start, path = test_planner.a_star(start, end)
#
# TypeError: cannot unpack non-iterable int object

# %%
p = np.array(path)

fig, ax = plt.subplots()
ax.imshow(img)
ax.plot(p[:, 0], p[:, 1])
